# %%
print("""
*****************************
          ATM 
*****************************
İşlemler
*********
1.Para yatırma
2.Para çekme
3.Fatura ödeme
 a="Elektrik Faturası"
 b="Su Faturası"
 c="Doğal Gaz Faturası"
 d="GSM & TV Faturası"
4.Bakiye sorgulama
5.Para tranferi
 x="Hesaplarım Arası"
 y="EFT"
6.Çıkış
*****************************
""")
bakiye=10000
while True:
    işlem=input("Lütfen yapmak istediğiniz işlem numarasını giriniz: ")
    if işlem=="6":
        print("Yine Bekleriz...")
        break
    elif işlem=="1":
        print("Lütfen parayı ekranda görüldüğü gibi yerleştiriniz")
        ekle=int(input("Eklemek istediğiniz tutar: "))
        bakiye+=ekle
        print("Eklenen Miktar: {} Güncel bakiye :{} ".format(ekle,bakiye))
        if ekle<0:
                print("Lütfen Geçerli Bir İşlem Yapınız")
    elif işlem =="2":
        çekme=int(input("Lütfen çekmek istediğiniz tutarı giriniz: "))
        bakiye-=çekme
        print("Çekilen Miktar: {}  Kalan Bakiye: {} ".format(çekme,bakiye))
        if bakiye<0:
                print("Lütfen Bakiyenizi Aşmayacak Şekilde Tuşlama Yapınız!")
        elif çekme<0:
                print("Lütfen Geçerli Bir İşlem Yapınız")
    elif işlem=="3":
        a="Elektrik Faturası"
        b="Su Faturası"
        c="Doğal Gaz Faturası"
        d="GSM & TV Faturası"
        fatura=input("Lütfen ödemek istediğiniz bir faturayı seçiniz: ")
        ödeme=int(input("Ödeme tutarını giriniz: "))
        bakiye-=ödeme
        print("Ödenen Miktar: {}  Kalan Bakiye: {}".format(ödeme,bakiye))
        if bakiye<0:
                print("Lütfen Bakiyenizi Aşmayacak Şekilde Tuşlama Yapınız!")
        elif ödeme<0:
                print("Lütfen Geçerli Bir İşlem Yapınız")
    elif işlem=="4":
        print("Güncel Bakiyeniz: ",bakiye)
    elif işlem=="5":
        x="Hesaplarım Arası"
        y="EFT"
        seçenek=input("Yapacağınız işlemi seçiniz: ")
        if seçenek=="Hesaplarım Arası":
            virman=int(input("Göndereceğiniz tutarı giriniz: "))
            print("Gönderilen Bakiye: {}  Bu Hesapta Kalan Bakiye: {} = Toplam Bakiye: {}".format(virman,(bakiye-virman),bakiye))
            if virman>bakiye:
                print("Lütfen Bakiyenizi Aşmayacak Şekilde Tuşlama Yapınız!")
            elif virman<0:
                print("Lütfen Geçerli Bir İşlem Yapınız")
        elif seçenek=="EFT":
            q=input("IBAN: ")
            w=input("Kart Sahibi: ")
            s=int(input("Göndereceğiniz Tutar: "))
            bakiye-=s
            print("Dekont\n IBN: {} Kart Sahibi: {} Gönderilen Tutar: {}".format(q,w,s))
            print("Güncel Bakiye: ",bakiye)
            if bakiye<0:
                print("Lütfen Bakiyenizi Aşmayacak Şekilde Tuşlama Yapınız!")
            elif s<0:
                print("Lütfen Geçerli Bir İşlem Yapınız")
        else:
            print("Hatalı Bir Tuşlama Yaptınız!")
    else:
        print("Hatalı Bir Tuşlama Yaptınız!")
# Out:
# *****************************
#           ATM
# *****************************
# İşlemler
# *********
# 1.Para yatırma
# 2.Para çekme
# 3.Fatura ödeme
#  a="Elektrik Faturası"
#  b="Su Faturası"
#  c="Doğal Gaz Faturası"
#  d="GSM & TV Faturası"
# 4.Bakiye sorgulama
# 5.Para tranferi
#  x="Hesaplarım Arası"
#  y="EFT"
# 6.Çıkış
# *****************************
#
# Lütfen yapmak istediğiniz işlem numarasını giriniz: 1
# Lütfen parayı ekranda görüldüğü gibi yerleştiriniz
# Eklemek istediğiniz tutar: 25
# Eklenen Miktar: 25 Güncel bakiye :10025
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13480/1054106562.py in <module>
#      21 bakiye=10000
#      22 while True:
# ---> 23     işlem=input("Lütfen yapmak istediğiniz işlem numarasını giriniz: ")
#      24     if işlem=="6":
#      25         print("Yine Bekleriz...")
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1004                 "raw_input was called, but this frontend does not support input requests."
#    1005             )
# -> 1006         return self._input_request(
#    1007             str(prompt),
#    1008             self._parent_ident["shell"],
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1049             except KeyboardInterrupt:
#    1050                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1051                 raise KeyboardInterrupt("Interrupted by user") from None
#    1052             except Exception:
#    1053                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
